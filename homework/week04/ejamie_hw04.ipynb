# %%
import pandas as pd

print(pd.__version__)

filename = "cleaned_census_tracts.csv"
df = pd.read_csv(filename)
# Out:
# 3.0.5

# %%
df.head()
# Out:
#    OBJECTID  STATEFP  COUNTYFP              County  TRACTCE       GEOID  \
# 0         3        6        37  Los Angeles County   204920  6037204920
# 1         4        6        37  Los Angeles County   205110  6037205110
# 2         5        6        37  Los Angeles County   205120  6037205120
# 3         6        6        37  Los Angeles County   206010  6037206010
# 4         8        6        37  Los Angeles County   206050  6037206050
#
#      NAME              NAMELSAD    ALAND  AWATER                      DAC  \
# 0  2049.2  Census Tract 2049.20   909972       0  Disadvantaged Community
# 1  2051.1  Census Tract 2051.10   286960       0  Disadvantaged Community
# 2  2051.2  Census Tract 2051.20  1466130       0  Disadvantaged Community
# 3  2060.1  Census Tract 2060.10  1418138   20551  Disadvantaged Community
# 4  2060.5  Census Tract 2060.50  1643426   94606  Disadvantaged Community
#
#   Income_Group Urban_Rural_RuralCenter  PerCap_100k_L2DCFC DAC_andor_LIC  \
# ...

# %%
df.shape
# Out:
# (2310, 19)

# %%
df.columns
# Out:
# Index(['OBJECTID', 'STATEFP', 'COUNTYFP', 'County', 'TRACTCE', 'GEOID', 'NAME',
#        'NAMELSAD', 'ALAND', 'AWATER', 'DAC', 'Income_Group',
#        'Urban_Rural_RuralCenter', 'PerCap_100k_L2DCFC', 'DAC_andor_LIC',
#        'UCC_eligible', 'REV2_eligible', 'Shape__Area', 'Shape__Length'],
#       dtype='str')

# %%
df.dtypes
# Out:
# OBJECTID                     int64
# STATEFP                      int64
# COUNTYFP                     int64
# County                         str
# TRACTCE                      int64
# GEOID                        int64
# NAME                       float64
# NAMELSAD                       str
# ALAND                        int64
# AWATER                       int64
# DAC                            str
# Income_Group                   str
# Urban_Rural_RuralCenter        str
# PerCap_100k_L2DCFC         float64
# DAC_andor_LIC                  str
# UCC_eligible                   str
# REV2_eligible                  str
# Shape__Area                float64
# Shape__Length              float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2310 entries, 0 to 2309
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   OBJECTID                 2310 non-null   int64
#  1   STATEFP                  2310 non-null   int64
#  2   COUNTYFP                 2310 non-null   int64
#  3   County                   2310 non-null   str
#  4   TRACTCE                  2310 non-null   int64
#  5   GEOID                    2310 non-null   int64
#  6   NAME                     2310 non-null   float64
#  7   NAMELSAD                 2310 non-null   str
#  8   ALAND                    2310 non-null   int64
#  9   AWATER                   2310 non-null   int64
#  10  DAC                      2310 non-null   str
#  11  Income_Group             2294 non-null   str
#  12  Urban_Rural_RuralCenter  2310 non-null   str
#  13  PerCap_100k_L2DCFC       2300 non-null   float64
# ...

# %%
mask = df["Income_Group"] == "Low"
df2 = df[mask]
df2
# Out:
#       OBJECTID  STATEFP  COUNTYFP              County  TRACTCE       GEOID  \
# 0            3        6        37  Los Angeles County   204920  6037204920
# 1            4        6        37  Los Angeles County   205110  6037205110
# 2            5        6        37  Los Angeles County   205120  6037205120
# 3            6        6        37  Los Angeles County   206010  6037206010
# 4            8        6        37  Los Angeles County   206050  6037206050
# ...        ...      ...       ...                 ...      ...         ...
# 2305      8033        6        37  Los Angeles County   603302  6037603302
# 2306      8034        6        37  Los Angeles County   603400  6037603400
# 2307      8035        6        37  Los Angeles County   603500  6037603500
# 2308      8037        6        85  Santa Clara County   512603  6085512603
# 2309      8041        6        37  Los Angeles County   603702  6037603702
#
# ...
